# %%
import pandas as pd

# %%
filepath="SALARY/Employees salary.csv"
df=pd.read_csv(filepath)
df
# Out:
#        FIRST_NAME  LAST_NAME            Combo Name              DEPARTMENT  \
# 0       CATHERINE      ABALO      ABALO, CATHERINE   Kane Regional Centers
# 1         KEVIN J     ABBOTT       ABBOTT, KEVIN J    Emergency Management
# 2           JOY M     ABBOTT         ABBOTT, JOY M   Kane Regional Centers
# 3     ELIZABETH S    ABRAHAM  ABRAHAM, ELIZABETH S                   Parks
# 4         JASMINE      ABRAM        ABRAM, JASMINE    Emergency Management
# ...           ...        ...                   ...                     ...
# 6275         ILAN        ZUR             ZUR, ILAN       District Attorney
# 6276   JEFFREY M.    ZURISKO   ZURISKO, JEFFREY M.       District Attorney
# 6277       MARY E    ZUSINAS       ZUSINAS, MARY E  Public Works Operating
# 6278      STEPHEN  ZVOLENSKY    ZVOLENSKY, STEPHEN                   Parks
# 6279       STEVEN  ZWOLINSKI     ZWOLINSKI, STEVEN  Information Technology
#
# ...

# %%
df.isnull()
#to find rows with missing values it will bring true
# Out:
#       FIRST_NAME  LAST_NAME  Combo Name  DEPARTMENT  JOB_TITLE  \
# 0          False      False       False       False      False
# 1          False      False       False       False      False
# 2          False      False       False       False      False
# 3          False      False       False       False      False
# 4          False      False       False       False      False
# ...          ...        ...         ...         ...        ...
# 6275       False      False       False       False      False
# 6276       False      False       False       False      False
# 6277       False      False       False       False      False
# 6278       False      False       False       False      False
# 6279       False      False       False       False      False
#
#       ELECTED_OFFICIAL  DATE_STARTED    SEX  ETHNICITY  ORIG_START  DATE_TERM  \
# 0                False         False  False      False       False       True
# ...

# %%
df.isnull().sum()
#returns total number of missing values per column
# Out:
# FIRST_NAME             0
# LAST_NAME              0
# Combo Name             0
# DEPARTMENT             0
# JOB_TITLE              0
# ELECTED_OFFICIAL       0
# DATE_STARTED           0
# SEX                    0
# ETHNICITY              0
# ORIG_START             0
# DATE_TERM           5017
# PAY_STATUS             0
#  ANNUAL_SALARY         0
#  REGULAR_PAY           0
#  OVERTIME_PAY          0
#  INCENTIVE_PAY         0
#  GROSS_PAY             0
# Unnamed: 17         6279
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
#used to find exact value missing 
df
# Out:
#        FIRST_NAME  LAST_NAME            Combo Name              DEPARTMENT  \
# 0       CATHERINE      ABALO      ABALO, CATHERINE   Kane Regional Centers
# 1         KEVIN J     ABBOTT       ABBOTT, KEVIN J    Emergency Management
# 2           JOY M     ABBOTT         ABBOTT, JOY M   Kane Regional Centers
# 3     ELIZABETH S    ABRAHAM  ABRAHAM, ELIZABETH S                   Parks
# 4         JASMINE      ABRAM        ABRAM, JASMINE    Emergency Management
# ...           ...        ...                   ...                     ...
# 6275         ILAN        ZUR             ZUR, ILAN       District Attorney
# 6276   JEFFREY M.    ZURISKO   ZURISKO, JEFFREY M.       District Attorney
# 6277       MARY E    ZUSINAS       ZUSINAS, MARY E  Public Works Operating
# 6278      STEPHEN  ZVOLENSKY    ZVOLENSKY, STEPHEN                   Parks
# 6279       STEVEN  ZWOLINSKI     ZWOLINSKI, STEVEN  Information Technology
#
# ...

# %%
df.fillna(value={'Date term':'Unknown'},inplace=True)
df.head()
#replaces the blank space with unknown
# Out:
#     FIRST_NAME LAST_NAME            Combo Name             DEPARTMENT  \
# 0    CATHERINE     ABALO      ABALO, CATHERINE  Kane Regional Centers
# 1      KEVIN J    ABBOTT       ABBOTT, KEVIN J   Emergency Management
# 2        JOY M    ABBOTT         ABBOTT, JOY M  Kane Regional Centers
# 3  ELIZABETH S   ABRAHAM  ABRAHAM, ELIZABETH S                  Parks
# 4      JASMINE     ABRAM        ABRAM, JASMINE   Emergency Management
#
#                      JOB_TITLE  ELECTED_OFFICIAL DATE_STARTED SEX  \
# 0            NURSING ASSISTANT                 0     4/8/2010   F
# 1  FIRE INSTRUCTOR - PART TIME                 0    6/11/2018   M
# 2                         COOK                 0    2/14/1999   F
# 3                SEASONAL AIDE                 0    5/26/2022   F
# 4    TELECOMMUNICATION OFFICER                 0    5/23/2022   F
#
#                         ETHNICITY ORIG_START DATE_TERM  PAY_STATUS  \
# 0                           Black   7/6/2009       NaN      Active
# ...

# %%
df[df.duplicated()]#drop duplicates 
df
# Out:
#        FIRST_NAME  LAST_NAME            Combo Name              DEPARTMENT  \
# 0       CATHERINE      ABALO      ABALO, CATHERINE   Kane Regional Centers
# 1         KEVIN J     ABBOTT       ABBOTT, KEVIN J    Emergency Management
# 2           JOY M     ABBOTT         ABBOTT, JOY M   Kane Regional Centers
# 3     ELIZABETH S    ABRAHAM  ABRAHAM, ELIZABETH S                   Parks
# 4         JASMINE      ABRAM        ABRAM, JASMINE    Emergency Management
# ...           ...        ...                   ...                     ...
# 6275         ILAN        ZUR             ZUR, ILAN       District Attorney
# 6276   JEFFREY M.    ZURISKO   ZURISKO, JEFFREY M.       District Attorney
# 6277       MARY E    ZUSINAS       ZUSINAS, MARY E  Public Works Operating
# 6278      STEPHEN  ZVOLENSKY    ZVOLENSKY, STEPHEN                   Parks
# 6279       STEVEN  ZWOLINSKI     ZWOLINSKI, STEVEN  Information Technology
#
# ...
